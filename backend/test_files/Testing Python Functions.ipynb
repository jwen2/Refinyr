# %%
import pandas as pd
import numpy as np
import matplotlib as mb
import seaborn as sns

# %%
df = pd.read_csv("MOCK_DATA.csv")

# %%
df.head()
# Out:
#    id   first_name   last_name                                email  gender  \
# 0   1       Salomo       Skill          sskill0@businessinsider.com    Male
# 1   2         Dido      Breche              dbreche1@privacy.gov.au  Female
# 2   3  Christoforo  McClements           cmcclements2@economist.com    Male
# 3   4         Rufe      Dyball                   rdyball3@chron.com    Male
# 4   5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org    Male
#
#         ip_address
# 0    85.107.11.136
# 1  127.100.218.211
# 2    66.84.129.212
# 3   233.172.18.148
# 4  178.234.135.183

# %%
A = 'Male' in df["gender"].unique()
print(A)
# Out:
# True

# %%
def value_editor(df, col_name, old_value, new_value):
    if old_value in df[col_name].unique():
        NewColumn = df[col_name].replace({old_value : new_value})
        Newdf = df
        Newdf[col_name] = NewColumn
        return Newdf
    else: 
        return ("Error could not find value")

# %%
B = value_editor(df, 'gender', 'Male', "X")

# %%
B.head()
# Out:
#    id   first_name   last_name                                email  gender  \
# 0   1       Salomo       Skill          sskill0@businessinsider.com       X
# 1   2         Dido      Breche              dbreche1@privacy.gov.au  Female
# 2   3  Christoforo  McClements           cmcclements2@economist.com       X
# 3   4         Rufe      Dyball                   rdyball3@chron.com       X
# 4   5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org       X
#
#         ip_address
# 0    85.107.11.136
# 1  127.100.218.211
# 2    66.84.129.212
# 3   233.172.18.148
# 4  178.234.135.183

# %%
C = df['gender'].replace({'Male':'X'})

# %%
C.head()
# Out:
# 0         X
# 1    Female
# 2         X
# 3         X
# 4         X
# Name: gender, dtype: object

# %%
def transformer(df, col_name, x):
    if df[col_name].dtypes == "int64":
        if x == "squared":
            df[col_name+"_squared"] = df[col_name] * df[col_name]
            return (df)
        if x == "log":
            df[col_name+"_ln"] = np.log(df[col_name])
            return (df)
        if x == "root2":
            df[col_name+"_root2"] = np.sqrt(df[col_name])
            return (df)
    else: 
        return ("Can not apply transformation to none numeric column")

# %%
transformer(df,'id','squared')
# Out:
#        id   first_name   last_name                                email  \
# 0       1       Salomo       Skill          sskill0@businessinsider.com
# 1       2         Dido      Breche              dbreche1@privacy.gov.au
# 2       3  Christoforo  McClements           cmcclements2@economist.com
# 3       4         Rufe      Dyball                   rdyball3@chron.com
# 4       5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org
# ..    ...          ...         ...                                  ...
# 995   996       Debora     McIlory             dmciloryrn@wordpress.org
# 996   997         Dion   Lowbridge               dlowbridgero@wikia.com
# 997   998       Herman     Birrane                 hbirranerp@yandex.ru
# 998   999        Belle      Batrim              bbatrimrq@moonfruit.com
# 999  1000      Auberon      Wonfor              awonforrr@shinystat.com
#
#      gender       ip_address  id_squared
# 0         X    85.107.11.136           1
# 1    Female  127.100.218.211           4
# 2         X    66.84.129.212           9
# 3         X   233.172.18.148          16
# 4         X  178.234.135.183          25
# ..      ...              ...         ...
# 995  Female   171.62.120.106      992016
# 996  Female   152.17.244.215      994009
# 997       X      42.39.83.83      996004
# 998  Female     23.207.15.63      998001
# 999       X   219.21.232.186     1000000
#
# [1000 rows x 7 columns]

# %%
transformer(df,'id','log')
# Out:
#        id   first_name   last_name                                email  \
# 0       1       Salomo       Skill          sskill0@businessinsider.com
# 1       2         Dido      Breche              dbreche1@privacy.gov.au
# 2       3  Christoforo  McClements           cmcclements2@economist.com
# 3       4         Rufe      Dyball                   rdyball3@chron.com
# 4       5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org
# ..    ...          ...         ...                                  ...
# 995   996       Debora     McIlory             dmciloryrn@wordpress.org
# 996   997         Dion   Lowbridge               dlowbridgero@wikia.com
# 997   998       Herman     Birrane                 hbirranerp@yandex.ru
# 998   999        Belle      Batrim              bbatrimrq@moonfruit.com
# 999  1000      Auberon      Wonfor              awonforrr@shinystat.com
#
#      gender       ip_address  id_squared     id_ln
# 0         X    85.107.11.136           1  0.000000
# 1    Female  127.100.218.211           4  0.693147
# 2         X    66.84.129.212           9  1.098612
# 3         X   233.172.18.148          16  1.386294
# 4         X  178.234.135.183          25  1.609438
# ..      ...              ...         ...       ...
# 995  Female   171.62.120.106      992016  6.903747
# 996  Female   152.17.244.215      994009  6.904751
# 997       X      42.39.83.83      996004  6.905753
# 998  Female     23.207.15.63      998001  6.906755
# 999       X   219.21.232.186     1000000  6.907755
#
# [1000 rows x 8 columns]

# %%
transformer(df,'id','root2')
# Out:
#        id   first_name   last_name                                email  \
# 0       1       Salomo       Skill          sskill0@businessinsider.com
# 1       2         Dido      Breche              dbreche1@privacy.gov.au
# 2       3  Christoforo  McClements           cmcclements2@economist.com
# 3       4         Rufe      Dyball                   rdyball3@chron.com
# 4       5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org
# ..    ...          ...         ...                                  ...
# 995   996       Debora     McIlory             dmciloryrn@wordpress.org
# 996   997         Dion   Lowbridge               dlowbridgero@wikia.com
# 997   998       Herman     Birrane                 hbirranerp@yandex.ru
# 998   999        Belle      Batrim              bbatrimrq@moonfruit.com
# 999  1000      Auberon      Wonfor              awonforrr@shinystat.com
#
#      gender       ip_address  id_squared     id_ln   id_root2
# 0         X    85.107.11.136           1  0.000000   1.000000
# 1    Female  127.100.218.211           4  0.693147   1.414214
# 2         X    66.84.129.212           9  1.098612   1.732051
# 3         X   233.172.18.148          16  1.386294   2.000000
# 4         X  178.234.135.183          25  1.609438   2.236068
# ..      ...              ...         ...       ...        ...
# 995  Female   171.62.120.106      992016  6.903747  31.559468
# 996  Female   152.17.244.215      994009  6.904751  31.575307
# 997       X      42.39.83.83      996004  6.905753  31.591138
# 998  Female     23.207.15.63      998001  6.906755  31.606961
# 999       X   219.21.232.186     1000000  6.907755  31.622777
#
# [1000 rows x 9 columns]

# %%
df['id'].dtype == "int64"
# Out:
# True

# %%
### function to delete a column based off of column name

# %%
df2 = pd.read_csv("cereal.csv")

# %%
df2.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
def quartile_trimmer(df, col_name, n):
    transformed = "clipped_" + col_name
    upper = df[col_name].quantile(1-n)
    lower = df[col_name].quantile(n)
    df[transformed] = df[col_name].clip(lower, upper, axis = 0)
    return df

# %%
df4 = (quartile_trimmer(df2, "sodium", 0.05))

# %%
df4.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#    clipped_sodium
# 0           130.0
# 1            15.0
# 2           260.0
# 3           140.0
# 4           200.0

# %%
df2["sodium"].quantile(0.95)
# Out:
# 282.0

# %%
def histogram (df, col_name):
    return df[col_name].hist()

# %%
df2['protein'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='shelf', data=df2)
# Out:
# <AxesSubplot:xlabel='shelf', ylabel='count'>
