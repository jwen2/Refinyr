# %%
import pandas as pd
import numpy as np
import matplotlib as mb
import seaborn as sns
import datetime

# %%
df = pd.read_csv("MOCK_DATA.csv")

# %%
df
# Out:
#        id   first_name   last_name                                email  \
# 0       1       Salomo       Skill          sskill0@businessinsider.com
# 1       2         Dido      Breche              dbreche1@privacy.gov.au
# 2       3  Christoforo  McClements           cmcclements2@economist.com
# 3       4         Rufe      Dyball                   rdyball3@chron.com
# 4       5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org
# ..    ...          ...         ...                                  ...
# 995   996       Debora     McIlory             dmciloryrn@wordpress.org
# 996   997         Dion   Lowbridge               dlowbridgero@wikia.com
# 997   998       Herman     Birrane                 hbirranerp@yandex.ru
# 998   999        Belle      Batrim              bbatrimrq@moonfruit.com
# 999  1000      Auberon      Wonfor              awonforrr@shinystat.com
#
#      gender       ip_address
# 0      Male    85.107.11.136
# 1    Female  127.100.218.211
# 2      Male    66.84.129.212
# 3      Male   233.172.18.148
# 4      Male  178.234.135.183
# ..      ...              ...
# 995  Female   171.62.120.106
# 996  Female   152.17.244.215
# 997    Male      42.39.83.83
# 998  Female     23.207.15.63
# 999    Male   219.21.232.186
#
# [1000 rows x 6 columns]

# %%
df.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# ip_address    object
# dtype: object

# %%
df["first_name"].dtypes
# Out:
# dtype('O')

# %%
df["id"].dtypes
# Out:
# dtype('int64')

# %%
df["id"] = df["id"].astype(str)

# %%
df["id"].dtypes
# Out:
# dtype('O')

# %%
A = 'Male' in df["gender"].unique()
print(A)
# Out:
# True

# %%
def value_editor(df, col_name, old_value, new_value):
    if old_value in df[col_name].unique():
        NewColumn = df[col_name].replace({old_value : new_value})
        Newdf = df
        Newdf[col_name] = NewColumn
        return Newdf
    else: 
        return ("Error could not find value")

# %%
B = value_editor(df, 'gender', 'Male', "X")

# %%
B.head()
# Out:
#   id   first_name   last_name                                email  gender  \
# 0  1       Salomo       Skill          sskill0@businessinsider.com       X
# 1  2         Dido      Breche              dbreche1@privacy.gov.au  Female
# 2  3  Christoforo  McClements           cmcclements2@economist.com       X
# 3  4         Rufe      Dyball                   rdyball3@chron.com       X
# 4  5      Jackson  Noseworthy  jnoseworthy4@networkadvertising.org       X
#
#         ip_address
# 0    85.107.11.136
# 1  127.100.218.211
# 2    66.84.129.212
# 3   233.172.18.148
# 4  178.234.135.183

# %%
C = df['gender'].replace({'Male':'X'})

# %%
C.head()
# Out:
# 0         X
# 1    Female
# 2         X
# 3         X
# 4         X
# Name: gender, dtype: object

# %%
def transformer(df, col_name, x):
    if df[col_name].dtypes == "int64":
        if x == "squared":
            df[col_name+"_squared"] = df[col_name] * df[col_name]
            return (df)
        if x == "log":
            df[col_name+"_ln"] = np.log(df[col_name])
            return (df)
        if x == "root2":
            df[col_name+"_root2"] = np.sqrt(df[col_name])
            return (df)
    else: 
        return ("Can not apply transformation to none numeric column")

# %%
transformer(df,'id','squared')
# Out:
# 'Can not apply transformation to none numeric column'

# %%
transformer(df,'id','log')
# Out:
# 'Can not apply transformation to none numeric column'

# %%
transformer(df,'id','root2')
# Out:
# 'Can not apply transformation to none numeric column'

# %%
df['id'].dtype == "int64"
# Out:
# False

# %%
### function to delete a column based off of column name

# %%
df2 = pd.read_csv("cereal.csv")

# %%
df2.head()
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0                NaN   N    C      70.0        4    1   130.0   10.0    5.0
# 1  100% Natural Bran   Q    C     120.0        3    5    15.0    2.0    8.0
# 2           All-Bran   K    C      70.0        4    1   260.0    9.0    7.0
# 3                NaN   K    C      50.0        4    0   140.0   14.0    8.0
# 4     Almond Delight   R    C     110.0        2    2   200.0    1.0   14.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating       date
# 0     6.0   280.0      25.0    3.0     1.0  0.33  68.402973   5/9/2022
# 1     8.0   135.0       0.0    3.0     1.0  1.00  33.983679  5/10/2022
# 2     5.0   320.0      25.0    3.0     1.0  0.33  59.425505  5/11/2022
# 3     0.0   330.0      25.0    3.0     1.0  0.50  93.704912  5/12/2022
# 4     8.0    -1.0      25.0    NaN     1.0  0.75  34.384843  5/13/2022

# %%
df2["sodium"].max()
# Out:
# 320.0

# %%
def quartile_trimmer(df, col_name, n):
    transformed = "clipped_" + col_name
    upper = df[col_name].quantile(1-n)
    lower = df[col_name].quantile(n)
    df[transformed] = df[col_name].clip(lower, upper, axis = 0)
    return df

# %%
(quartile_trimmer(df2, "sodium", 0.05))
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   NaN   N    C      70.0        4    1   130.0   10.0
# 1     100% Natural Bran   Q    C     120.0        3    5    15.0    2.0
# 2              All-Bran   K    C      70.0        4    1   260.0    9.0
# 3                   NaN   K    C      50.0        4    0   140.0   14.0
# 4        Almond Delight   R    C     110.0        2    2   200.0    1.0
# ..                  ...  ..  ...       ...      ...  ...     ...    ...
# 75             Wheaties   G    C     100.0        3    1   200.0    3.0
# 76  Wheaties Honey Gold   G    C     110.0        2    1   200.0    1.0
# 77            Corn Pops   K    C     110.0        1    0    90.0    1.0
# 78            Corn Pops   K    C     110.0        1    0    90.0    1.0
# 79            Corn Pops   K    C     110.0        1    0    90.0    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0     6.0   280.0      25.0    3.0     1.0  0.33  68.402973
# 1     8.0     8.0   135.0       0.0    3.0     1.0  1.00  33.983679
# 2     7.0     5.0   320.0      25.0    3.0     1.0  0.33  59.425505
# 3     8.0     0.0   330.0      25.0    3.0     1.0  0.50  93.704912
# 4    14.0     8.0    -1.0      25.0    NaN     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 75   17.0     3.0   110.0      25.0    1.0     1.0  1.00  51.592193
# 76   16.0     8.0    60.0      25.0    1.0     1.0  0.75  36.187559
# 77   13.0    12.0    20.0      25.0    2.0     1.0  1.00  35.782791
# 78   13.0    12.0    20.0      25.0    2.0     1.0  1.00  35.782791
# 79   13.0    12.0    20.0      25.0    2.0     1.0  1.00  35.782791
#
#          date  clipped_sodium
# 0    5/9/2022           130.0
# 1   5/10/2022            15.0
# 2   5/11/2022           260.0
# 3   5/12/2022           140.0
# 4   5/13/2022           200.0
# ..        ...             ...
# 75  7/23/2022           200.0
# 76  7/24/2022           200.0
# 77  7/25/2022            90.0
# 78  7/26/2022            90.0
# 79  7/27/2022            90.0
#
# [80 rows x 18 columns]

# %%
df4["clipped_sodium"].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 df4["clipped_sodium"].max()
#
# NameError: name 'df4' is not defined

# %%
df2["sodium"].quantile(0.95)

# %%
def histogram (df, col_name):
    return df[col_name].hist()

# %%
df2['protein'].hist()

# %%
sns.countplot(x='shelf', data=df2)

# %%
df = pd.read_csv("datetest.csv")

# %%
df.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    655269             53478       63558  86.54         67        22807
# 1    723482             55513       63163  89.45         67        22807
# 2    758529             65282       84320  79.93         78        23135
# 3    763449             46905       63896  76.58         78        17014
# 4    708663             51428       63896  86.08         78        17014
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1497      01-01-74        Salaried  ...
# 1               45                1497      20-05-85   Self employed  ...
# 2               86                2071      14-10-95        Salaried  ...
# 3               45                2070      01-06-73   Self employed  ...
# 4               45                2069      01-06-72        Salaried  ...
#
#   SEC.CURRENT.BALANCE  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# 0                   0                      0                     0
# 1                   0                      0                     0
# 2                   0                      0                     0
# 3                   0                      0                     0
# 4                   0                      0                     0
#
#    PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# 0                   0               0                             0
# 1                5605               0                             1
# 2                   0               0                             0
# 3                   0               0                             0
# 4                   0               0                             0
#
#    DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  AVERAGE.ACCT.AGE  \
# 0                                    0         0yrs 0mon
# 1                                    0         0yrs 8mon
# 2                                    0         0yrs 0mon
# 3                                    0         2yrs 5mon
# 4                                    0         0yrs 0mon
#
#    CREDIT.HISTORY.LENGTH  NO.OF_INQUIRIES
# 0              0yrs 0mon                0
# 1              1yrs 0mon                1
# 2              0yrs 0mon                0
# 3              2yrs 5mon                0
# 4              0yrs 0mon                0
#
# [5 rows x 40 columns]

# %%
df['Date.of.Birth'].dtype
# Out:
# dtype('O')

# %%
df['Date.of.Birth']= pd.to_datetime(df['Date.of.Birth'])

# %%
df['Date.of.Birth'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['asset_cost']= pd.to_datetime(df['asset_cost'])

# %%
df['asset_cost'].dtype
# Out:
# dtype('<M8[ns]')

# %%
def dateTransformer(df, col_name, t):
    df[col_name] = pd.to_datetime(df[col_name])
    if t == 'day':
        df[col_name+"_day"] = df[col_name].dt.day
        return df
    elif t == 'month':
        df[col_name+"_month"] = df[col_name].dt.month
        return df
    elif t == 'year':
        df[col_name+"_year"] = df[col_name].dt.year
        return df
    elif t == 'quarter':
        df[col_name+"_quarter"] = df[col_name].dt.quarter
        return df
    elif t == 'dayofweek':
        df[col_name+"_dayofweek"] = df[col_name].dt.dayofweek
        return df
    elif t == 'weekday':
        df[col_name+"_weekday"] = df[col_name].dt.day_name()
        return df
    else: 
        return df

# %%
x = dateTransformer(df, 'Date.of.Birth', 'weekday')

# %%
x
# Out:
#         UniqueID  disbursed_amount                    asset_cost    ltv  \
# 0         655269             53478 1970-01-01 00:00:00.000063558  86.54
# 1         723482             55513 1970-01-01 00:00:00.000063163  89.45
# 2         758529             65282 1970-01-01 00:00:00.000084320  79.93
# 3         763449             46905 1970-01-01 00:00:00.000063896  76.58
# 4         708663             51428 1970-01-01 00:00:00.000063896  86.08
# ...          ...               ...                           ...    ...
# 112387    755547             44875 1970-01-01 00:00:00.000072509  67.58
# 112388    716994             53549 1970-01-01 00:00:00.000072509  78.61
# 112389    709352             55243 1970-01-01 00:00:00.000072509  81.37
# 112390    699795             55243 1970-01-01 00:00:00.000072509  81.37
# 112391    755244             40274 1970-01-01 00:00:00.000072509  60.68
#
#         branch_id  supplier_id  manufacturer_id  Current_pincode_ID  \
# 0              67        22807               45                1497
# 1              67        22807               45                1497
# 2              78        23135               86                2071
# 3              78        17014               45                2070
# 4              78        17014               45                2069
# ...           ...          ...              ...                 ...
# 112387         74        16646               86                2591
# 112388         74        16646               86                2593
# 112389         74        16646               86                2593
# 112390         74        16646               86                2593
# 112391         74        16646               86                2593
#
#        Date.of.Birth Employment.Type  ... SEC.SANCTIONED.AMOUNT  \
# 0         1974-01-01        Salaried  ...                     0
# 1         1985-05-20   Self employed  ...                     0
# 2         1995-10-14        Salaried  ...                     0
# 3         1973-01-06   Self employed  ...                     0
# 4         1972-01-06        Salaried  ...                     0
# ...              ...             ...  ...                   ...
# 112387    1992-05-14   Self employed  ...                     0
# 112388    1984-04-24   Self employed  ...                     0
# 112389    1986-01-01   Self employed  ...                     0
# 112390    1973-01-01   Self employed  ...                     0
# 112391    1974-01-01   Self employed  ...                     0
#
#         SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  \
# 0                          0                   0               0
# 1                          0                5605               0
# 2                          0                   0               0
# 3                          0                   0               0
# 4                          0                   0               0
# ...                      ...                 ...             ...
# 112387                     0                   0               0
# 112388                     0                   0               0
# 112389                     0                   0               0
# 112390                     0                   0               0
# 112391                     0                   0               0
#
#         NEW.ACCTS.IN.LAST.SIX.MONTHS  DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  \
# 0                                  0                                    0
# 1                                  1                                    0
# 2                                  0                                    0
# 3                                  0                                    0
# 4                                  0                                    0
# ...                              ...                                  ...
# 112387                             0                                    0
# 112388                             0                                    0
# 112389                             0                                    0
# 112390                             1                                    1
# 112391                             0                                    0
#
#         AVERAGE.ACCT.AGE  CREDIT.HISTORY.LENGTH  NO.OF_INQUIRIES  \
# 0              0yrs 0mon              0yrs 0mon                0
# 1              0yrs 8mon              1yrs 0mon                1
# 2              0yrs 0mon              0yrs 0mon                0
# 3              2yrs 5mon              2yrs 5mon                0
# 4              0yrs 0mon              0yrs 0mon                0
# ...                  ...                    ...              ...
# 112387         0yrs 0mon              0yrs 0mon                0
# 112388         0yrs 0mon              0yrs 0mon                0
# 112389        4yrs 10mon              9yrs 5mon                0
# 112390         0yrs 3mon              0yrs 3mon                0
# 112391         0yrs 0mon              0yrs 0mon                0
#
#         Date.of.Birth_weekday
# 0                     Tuesday
# 1                      Monday
# 2                    Saturday
# 3                    Saturday
# 4                    Thursday
# ...                       ...
# 112387               Thursday
# 112388                Tuesday
# 112389              Wednesday
# 112390                 Monday
# 112391                Tuesday
#
# [112392 rows x 41 columns]

# %%
def remove_nulls(df, col_name):
    if df[col_name].isna().values.any():
        df = df.dropna(subset=[col_name])
        return df
    else:
        return "No Nulls"

# %%
df = pd.read_csv("drop_null.csv")

# %%
df.head()
# Out:
#      a  b  c
# 0  NaN  1  2
# 1  NaN  2  3
# 2  5.0  6  7

# %%
print (remove_nulls(df, 'a'))
# Out:
#      a  b  c
# 2  5.0  6  7

# %%
from scipy import stats

# %%
z_scores = stats.zscore(x["disbursed_amount"])

# %%
abs_z_scores = np.abs(z_scores)

# %%
filtered_entries = (abs_z_scores < 3)

# %%
new_df = x[filtered_entries]

# %%
new_df['disbursed_amount'].describe()
# Out:
# count    111123.000000
# mean      55514.819101
# std       11480.648201
# min       16759.000000
# 25%       48778.000000
# 50%       55259.000000
# 75%       61814.000000
# max       95429.000000
# Name: disbursed_amount, dtype: float64

# %%
x['disbursed_amount'].describe()
# Out:
# count    112392.000000
# mean      56076.803269
# std       13123.697627
# min       11613.000000
# 25%       48849.000000
# 50%       55359.000000
# 75%       62147.000000
# max      940690.000000
# Name: disbursed_amount, dtype: float64

# %%
def remove_outliers(df, col_name):
    z_scores = stats.zscore(df[col_name])
    abs_z_scores = np.abs(z_scores)
    filtered = (abs_z_scores < 3)
    updated_df = df[filtered]
    return updated_df

# %%
y = remove_outliers(x, "disbursed_amount")

# %%
y["disbursed_amount"].describe()
# Out:
# count    111123.000000
# mean      55514.819101
# std       11480.648201
# min       16759.000000
# 25%       48778.000000
# 50%       55259.000000
# 75%       61814.000000
# max       95429.000000
# Name: disbursed_amount, dtype: float64

# %%
newdf = pd.read_csv(""')

# %%
df = pd.read_csv("cNa.csv")

# %%
df.head()
# Out:
#     a     b       c
# 0   1   2.0   3.200
# 1   4   NaN   6.500
# 2   7   NaN   9.200
# 3  10  11.0  12.121
# 4  13  14.0  15.210

# %%
df.dtypes
# Out:
# a      int64
# b    float64
# c    float64
# dtype: object
